# %%
import ultralytics as ut

# %%
#YOLO 
import ultralytics as ut
from ultralytics import YOLO
#downloads yolo11 offline
model = YOLO('yolo11n.pt')
predict_class = [0,14]
img = '.\lio2.jpeg' 
pred = model(img , classes = predict_class, conf =.4)
pred_img = pred[0].plot()


import cv2
cv2.imwrite('image.jpg', pred_img)
cv2.waitKey(5000)
cv2.destroyAllWindows()
# Out:
# <>:7: SyntaxWarning: invalid escape sequence '\l'
# <>:7: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Aafreen\AppData\Local\Temp\ipykernel_18228\4184583689.py:7: SyntaxWarning: invalid escape sequence '\l'
#   img = '.\lio2.jpeg'
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 3.0MB/s 1.8s.8s<0.0s1.4s8s
#
# image 1/1 d:\iii\Open_CV\lio2.jpeg: 384x640 1 person, 78.5ms
# Speed: 4.8ms preprocess, 78.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
